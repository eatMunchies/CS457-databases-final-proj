# %%
print("test")
# import sklearn as sk
# from sklearn.ensemble import Random
# from sk.ensemble
# thing = sk.ensemble.RandomForestClassifier()
# Out:
# test

# %%
"""
This is for testing stuff
"""
# Out:
# '\nThis is for testing stuff\n'

# %%
# test future analyzer
from src.back.FutureAnalyzer import *
from src.back.models import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 2
#       1 # test future analyzer
# ----> 2 from src.back.FutureAnalyzer import *
#       3 from src.back.models import *
#
# File ~/Desktop/School/CS 457/final/src/back/FutureAnalyzer.py:10
#       1 """
#       2 Anthony Silva
#       3 CS 457
#    (...)
#       7 Description: This file contains the FutureAnalyzer class
#       8 """
# ---> 10 from back.Predictor import Predictor
#      11 from back.Visualizer import Visualizer
#      12 from back.StatisticsCalculator import StatisticsCalculator
#
# ModuleNotFoundError: No module named 'back'

# %%
myAnalyzer = FutureAnalyzer()

# %%
# test prediction

options = {
    'algorithm': 'linear regression',
    'column': 'open',
    'date': '2024-11-26',
    'metal': metals.gold
}

# prediction = myAnalyzer.predictor.runPredictions(myAnalyzer.data, options)
# prediction = myAnalyzer.predictFuturedata(options)


print(prediction)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 14
#       3 options = {
#       4     'algorithm': 'linear regression',
#       5     'column': 'open',
#       6     'date': '2024-11-26',
#       7     'metal': metals.gold
#       8 }
#      10 # prediction = myAnalyzer.predictor.runPredictions(myAnalyzer.data, options)
#      11 # prediction = myAnalyzer.predictFuturedata(options)
# ---> 14 print(prediction)
#
# NameError: name 'prediction' is not defined

# %%
# test visualization

options = {
    'graphType': 'line',
    # 'title': 'Open Copper Data',
    'xlabel': 'Date',
    'ylabel': 'Value',
    'color': 'blue',
    'x': 'date',
    'y': 'open',
    'metal': metals.gold,
    'outputPath': './data/images/'
}

# myAnalyzer.dataLoader(options['metal'])
# myAnalyzer.visualizer.visualizeData(myAnalyzer.data, options)

myAnalyzer.visualizeData(options)
# Out:
# Plot saved to ./data/images/

# %%
# test statistics

options = {
    'column': 'open',
    'metal': metals.gold,
    'range': None,
    'window': 10
}

calcs = myAnalyzer.produceStatistics(options)
print(calcs)
# Out:
# {'mean': np.float64(2.7286961206745435), 'median': np.float64(2.951499938964844), 'mode': 0    3.36
# Name: open, dtype: float64, 'variance': np.float64(1.234394082081585), 'standard deviation': np.float64(1.1110328897389063), 'volatility': np.float64(0.01659312019272957)}
# /home/anthony/Desktop/School/CS 457/final/src/back/FutureAnalyzer.py:110: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   value=float(value),

# %%
i am anthony silva and i am representign team 32
including myself, brandon ramirez, robert fleming, and austin parkerson. 
we are developing a new open source software called ABRA, 
which is a platform neutral container observation and orchestration platform.
if you are a system administrator, ABRA can help you turn your 9-5 workday
into a 9-1 workday so you can spend more time with your family and less time configuring services. 
ABRA lets you sync kernel level container restrictions across your entire infrastructure 
and serves as a siem system with environment wide logigng, user admin, and system cusotmization. 
ABRA integrates well into many different existing infrastructures to bridge the gap 
between what you could have and what you want to have
all through the power of the extended berkley packet filter. 
thank you.
# Out:
#   Cell In[25], line 1
#     i am anthony silva and i am showing our software: ABRA, which is a platform neutral container observation and orchestration
#       ^
# SyntaxError: invalid syntax
